# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
path = 'dehm_stations_data/'
str1 = 'co2conc01.00h'
str2 = ['','.z2','.z3','.z4']
str3 = '.jan.test'
str4 = ['','.2','.3','.4']
str5 = '.dat'

files = []
for lvl in str2:
    for nest in str4:
        files.append(path+str1+lvl+str3+nest+str5)

print(files[-1])
# Out:
# dehm_stations_data/co2conc01.00h.z4.jan.test.4.dat

# %%
print(record)
# Out:
# <_io.TextIOWrapper name='dehm_stations_data/co2conc01.00h.jan.test.dat' mode='r' encoding='UTF-8'>

# %%
ll = 76
size = [12, 12, 12, 12, 12, 16]

# %%
print(record.readline())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 print(record.readline())
#
# ValueError: I/O operation on closed file.

# %%
with open(files[0]) as record:
    for line in record
    
for i in range(6):
    print(line1[size*i:size*(i+1)])
#    for line in recordlines[0])
# Out:
#         2011           1           1           1           1   1.151896
#
#         2011           1           1           1           2  5.5624951E-05
#
#         2011
#            1
#            1
#            1
#            1
#    1.151896

# %% [markdown]
# ## def get_data(file_list):

# %%
fig = plt.figure(figsize=(12,5))
